# %%
from pymongo import MongoClient
import time
from pymongo import ASCENDING, DESCENDING

# %%
client = MongoClient("mongodb://localhost:27018/")
db = client["anime_database"]

# %% [markdown]
# ## JOVO GUŽVIĆ, IN61/2020

# %% [markdown]
# ### Za svaki žanr, pronaći anime sa najvećom prosečnom ocenom u tom žanru

# %%
pipeline1_opt = [
    {"$unwind": "$genre"},
    {"$group": {
        "_id": {
            "genre": "$genre",
            "anime_uid": "$uid",
            "title": "$title",
            "average_score": "$average_score"  
        },
        "max_average_score": {"$max": "$average_score"}
    }},
    {"$sort": {
        "_id.genre": 1,
        "max_average_score": -1
    }},
    {"$group": {
        "_id": "$_id.genre",
        "top_anime": {"$first": {
            "anime_uid": "$_id.anime_uid",
            "title": "$_id.title",
            "max_average_score": "$max_average_score"
        }}
    }},
    {"$sort": {
        "_id": 1
    }},
    {"$project": {
        "_id": 0,
        "genre": "$_id",
        "anime_uid": "$top_anime.anime_uid",
        "title": "$top_anime.title",
        "max_average_score": "$top_anime.max_average_score"
    }}
]


# Measure query execution time
start_time = time.time()
result1_opt = list(db.animes_opt.aggregate(pipeline1_opt))
end_time = time.time()
duration = end_time - start_time


# Print results and query duration
print("Top anime with highest average review score for each genre (optimized):", result1_opt)
print("Query duration:", duration, "seconds")
# Out:
# Top anime with highest average review score for each genre (optimized): [{'genre': 'Action', 'anime_uid': 38084, 'title': 'Fate/Grand Order: Zettai Majuu Sensen Babylonia', 'max_average_score': 10.0}, {'genre': 'Adventure', 'anime_uid': 996, 'title': 'Bishoujo Senshi Sailor Moon: Sailor Stars', 'max_average_score': 9.8}, {'genre': 'Cars', 'anime_uid': 388, 'title': 'Capeta', 'max_average_score': 9.0}, {'genre': 'Comedy', 'anime_uid': 22673, 'title': 'Kuroko no Basket 2nd Season NG-shuu', 'max_average_score': 10.0}, {'genre': 'Dementia', 'anime_uid': 934, 'title': 'Higurashi no Naku Koro ni', 'max_average_score': 8.625}, {'genre': 'Demons', 'anime_uid': 1253, 'title': 'Saint Seiya: Meiou Hades Meikai-hen', 'max_average_score': 9.0}, {'genre': 'Drama', 'anime_uid': 38250, 'title': 'Xiao Lu He Xiao Lan', 'max_average_score': 10.0}, {'genre': 'Ecchi', 'anime_uid': 268, 'title': 'Golden Boy', 'max_average_score': 8.542857142857143}, {'genre': 'Fantasy', 'anime_uid': 38084, 'title': 'Fate/Grand Order: Zettai Majuu Sensen Babylonia', 'max_average_score': 10.0}, {'genre': 'Game', 'anime_uid': 38250, 'title': 'Xiao Lu He Xiao Lan', 'max_average_score': 10.0}, {'genre': 'Harem', 'anime_uid': 10080, 'title': 'Kami nomi zo Shiru Sekai II', 'max_average_score': 9.0625}, {'genre': 'Historical', 'anime_uid': 2623, 'title': 'Flanders no Inu (Movie)', 'max_average_score': 9.666666666666666}, {'genre': 'Horror', 'anime_uid': 1571, 'title': 'Ghost Hunt', 'max_average_score': 8.666666666666666}, {'genre': 'Josei', 'anime_uid': 11113, 'title': 'Usagi Drop Specials', 'max_average_score': 10.0}, {'genre': 'Kids', 'anime_uid': 9204, 'title': 'Omae Umasou da na', 'max_average_score': 8.333333333333334}, {'genre': 'Magic', 'anime_uid': 38250, 'title': 'Xiao Lu He Xiao Lan', 'max_average_score': 10.0}, {'genre': 'Martial Arts', 'anime_uid': 967, 'title': 'Hokuto no Ken', 'max_average_score': 8.3}, {'genre': 'Mecha', 'anime_uid': 2904, 'title': 'Code Geass: Hangyaku no Lelouch R2', 'max_average_score': 9.421052631578947}, {'genre': 'Military', 'anime_uid': 397, 'title': 'Seikai no Senki II', 'max_average_score': 10.0}, {'genre': 'Music', 'anime_uid': 17949, 'title': 'The Everlasting Guilty Crown', 'max_average_score': 10.0}, {'genre': 'Mystery', 'anime_uid': 2618, 'title': 'Takarajima', 'max_average_score': 9.5}, {'genre': 'Parody', 'anime_uid': 918, 'title': 'Gintama', 'max_average_score': 9.25}, {'genre': 'Police', 'anime_uid': 38770, 'title': 'Detective Conan Movie 23: The Fist of Blue Sapphire', 'max_average_score': 9.0}, {'genre': 'Psychological', 'anime_uid': 793, 'title': 'xxxHOLiC Movie: Manatsu no Yoru no Yume', 'max_average_score': 9.0}, {'genre': 'Romance', 'anime_uid': 11001, 'title': 'Toshokan Sensou: Kakumei no Tsubasa', 'max_average_score': 10.0}, {'genre': 'Samurai', 'anime_uid': 9996, 'title': 'Hyouge Mono', 'max_average_score': 9.5}, {'genre': 'School', 'anime_uid': 38250, 'title': 'Xiao Lu He Xiao Lan', 'max_average_score': 10.0}, {'genre': 'Sci-Fi', 'anime_uid': 38250, 'title': 'Xiao Lu He Xiao Lan', 'max_average_score': 10.0}, {'genre': 'Seinen', 'anime_uid': 24921, 'title': 'Aoki Hagane no Arpeggio: Ars Nova Cadenza', 'max_average_score': 9.666666666666666}, {'genre': 'Shoujo', 'anime_uid': 996, 'title': 'Bishoujo Senshi Sailor Moon: Sailor Stars', 'max_average_score': 9.8}, {'genre': 'Shoujo Ai', 'anime_uid': 1729, 'title': 'Maria-sama ga Miteru 3rd', 'max_average_score': 8.666666666666666}, {'genre': 'Shounen', 'anime_uid': 36215, 'title': 'One Piece: Episode of East Blue - Luffy to 4-nin no Nakama no Daibouken', 'max_average_score': 9.5}, {'genre': 'Shounen Ai', 'anime_uid': 38250, 'title': 'Xiao Lu He Xiao Lan', 'max_average_score': 10.0}, {'genre': 'Slice of Life', 'anime_uid': 38250, 'title': 'Xiao Lu He Xiao Lan', 'max_average_score': 10.0}, {'genre': 'Space', 'anime_uid': 397, 'title': 'Seikai no Senki II', 'max_average_score': 10.0}, {'genre': 'Sports', 'anime_uid': 22673, 'title': 'Kuroko no Basket 2nd Season NG-shuu', 'ma ...
# Query duration: 0.2584187984466553 seconds

# %% [markdown]
# ### Za svaku godinu izračunaj prosek svih prosečnih ocena animea koji su počeli emitovanje date godine

# %%
# Define the aggregation pipeline for optimized collections
pipeline2_opt = [
    {"$match": {
        "start_years": {"$gt": 2000}
    }},
    {"$group": {
        "_id": "$start_years",
        "average_overall": {"$avg": "$average_score"},
        "average_story": {"$avg": "$average_story"},
        "average_animation": {"$avg": "$average_animation"},
        "average_sound": {"$avg": "$average_sound"},
        "average_character": {"$avg": "$average_character"},
        "average_enjoyment": {"$avg": "$average_enjoyment"}
    }},
    {"$project": {
        "_id": 1,
        "average_all": {
            "$avg": [
                "$average_overall",
                "$average_story",
                "$average_animation",
                "$average_sound",
                "$average_character",
                "$average_enjoyment"
            ]
        }
    }},
    {"$sort": {
        "_id": 1
    }}
]


# Measure query execution time
start_time = time.time()
result2_opt = list(db.animes_opt.aggregate(pipeline2_opt))
end_time = time.time()
duration = end_time - start_time

# Print results and query duration
print("Average of all average metrics for each year (optimized):", result2_opt)
print("Query duration:", duration, "seconds")
# Out:
# Average of all average metrics for each year (optimized): [{'_id': 2001.0, 'average_all': 8.203492063492064}, {'_id': 2002.0, 'average_all': 8.061814726452885}, {'_id': 2003.0, 'average_all': 8.390571782963088}, {'_id': 2004.0, 'average_all': 6.805144105144105}, {'_id': 2005.0, 'average_all': 8.318298059964727}, {'_id': 2006.0, 'average_all': 8.033311352128557}, {'_id': 2007.0, 'average_all': 8.296320346320346}, {'_id': 2008.0, 'average_all': 7.8821223270040415}, {'_id': 2009.0, 'average_all': 7.30168473808245}, {'_id': 2010.0, 'average_all': 8.052931912142439}, {'_id': 2011.0, 'average_all': 8.316095112970112}, {'_id': 2012.0, 'average_all': 7.687615828832104}, {'_id': 2013.0, 'average_all': 7.86227207136298}, {'_id': 2014.0, 'average_all': 7.640889539654245}, {'_id': 2015.0, 'average_all': 7.558856942091055}, {'_id': 2016.0, 'average_all': 7.151043169793169}, {'_id': 2017.0, 'average_all': 7.9352931758343415}, {'_id': 2018.0, 'average_all': 7.944210102960103}, {'_id': 2019.0, 'average_all': 7.4888616257037315}]
# Query duration: 0.025929689407348633 seconds

# %% [markdown]
# ### Pronađi top 3 animea koji imaju najveći prosek zbira Enjoyment i Sound ocena

# %%
pipeline3 = [
    {
        "$lookup": {
            "from": "animes_opt",
            "localField": "anime_uid",
            "foreignField": "uid",
            "as": "anime_info"
        }
    },
    {
        "$unwind": "$anime_info"
    },
    {
        "$unwind": "$anime_info.genre"
    },
    {
        "$group": {
            "_id": "$anime_info.genre",
            "average_enjoyment_sound": {"$avg": {"$avg": ["$scores.Enjoyment", "$scores.Sound"]}}
        }
    },
    {
        "$sort": {
            "average_enjoyment_sound": -1
        }
    },
    {
        "$limit": 3
    }
]

start_time = time.time()

result3 = db.reviews_opt.aggregate(pipeline3)

end_time = time.time()
duration = end_time - start_time

for record in result3:
    print(f"Genre: {record['_id']}, Average Enjoyment+Sound Score: {record['average_enjoyment_sound']}")
print("Query duration:", duration, "seconds")
# Out:
# Genre: Cars, Average Enjoyment+Sound Score: 8.6875
# Genre: Josei, Average Enjoyment+Sound Score: 8.382978723404255
# Genre: Parody, Average Enjoyment+Sound Score: 8.328260869565218
# Query duration: 0.2763948440551758 seconds

# %% [markdown]
# ### Za svaki žanr prikaži pol koji je animee u tom žanru ocenio najvećom prosečnom ocenom

# %%
pipeline4 = [
  {
    "$lookup": {
      "from": "animes_opt",
      "localField": "anime_uid",
      "foreignField": "uid",
      "as": "anime_info"
    }
  },
  {
    "$unwind": "$anime_info"
  },
  {
    "$lookup": {
      "from": "profiles_opt",
      "localField": "profile",
      "foreignField": "profile",
      "as": "profile_info"
    }
  },
  {
    "$unwind": "$profile_info"
  },
  {
    "$unwind": "$anime_info.genre"
  },
  {
    "$group": {
      "_id": {
        "genre": "$anime_info.genre",
        "gender": "$profile_info.gender"
      },
      "average_score": { "$avg": "$score" }
    }
  },
  {
    "$sort": {
      "_id.genre": 1,
      "average_score": -1
    }
  },
  {
    "$group": {
      "_id": "$_id.genre",
      "highest_avg_gender": { "$first": "$_id.gender" },
      "highest_avg_score": { "$first": "$average_score" }
    }
  },
  {
    "$sort": {
      "_id": 1
    }
  }
]

start_time = time.time()

# Execute the aggregation pipeline
result4 = db.reviews_opt.aggregate(pipeline4)

end_time = time.time()
duration = end_time - start_time

# Displaying the results
for record in result4:
    print(f"Genre: {record['_id']}, Gender: {record['highest_avg_gender']}, Average Score: {record['highest_avg_score']}")
print("Query duration:", duration, "seconds")
# Out:
# Genre: Action, Gender: Female, Average Score: 8.251984126984127
# Genre: Adventure, Gender: Non-Binary, Average Score: 8.266666666666667
# Genre: Cars, Gender: Male, Average Score: 8.5
# Genre: Comedy, Gender: Female, Average Score: 8.330275229357799
# Genre: Dementia, Gender: Male, Average Score: 8.19543973941368
# Genre: Demons, Gender: Female, Average Score: 8.526666666666667
# Genre: Drama, Gender: Female, Average Score: 8.333333333333334
# Genre: Ecchi, Gender: Male, Average Score: 8.10909090909091
# Genre: Fantasy, Gender: Non-Binary, Average Score: 8.533333333333333
# Genre: Game, Gender: Male, Average Score: 7.4873096446700504
# Genre: Harem, Gender: Male, Average Score: 9.071428571428571
# Genre: Historical, Gender: Female, Average Score: 8.766233766233766
# Genre: Horror, Gender: Female, Average Score: 8.271186440677965
# Genre: Josei, Gender: Non-Binary, Average Score: 9.5
# Genre: Kids, Gender: Male, Average Score: 8.08695652173913
# Genre: Magic, Gender: Non-Binary, Average Score: 9.0
# Genre: Martial Arts, Gender: Non-Binary, Average Score: 9.0
# Genre: Mecha, Gender: Male, Average Score: 8.348484848484848
# Genre: Military, Gender: Female, Average Score: 8.865384615384615
# Genre: Music, Gender: Female, Average Score: 8.40625
# Genre: Mystery, Gender: Female, Average Score: 8.381818181818181
# Genre: Parody, Gender: Male, Average Score: 8.417085427135678
# Genre: Police, Gender: Male, Average Score: 8.05
# Genre: Psychological, Gender: Female, Average Score: 8.074074074074074
# Genre: Romance, Gender: Female, Average Score: 8.228494623655914
# Genre: Samurai, Gender: Female, Average Score: 8.153846153846153
# Genre: School, Gender: Non-Binary, Average Score: 8.285714285714286
# Genre: Sci-Fi, Gender: Female, Average Score: 8.288235294117648
# Genre: Seinen, Gender: Female, Average Score: 8.311827956989248
# Genre: Shoujo, Gender: Female, Average Score: 8.710843373493976
# Genre: Shoujo Ai, Gender: Female, Average Score: 8.571428571428571
# Genre: Shounen, Gender: Female, Average Score: 8.337243401759531
# Genre: Shounen Ai, Gender: Non-Binary, Average Score: 10.0
# Genre: Slice of Life, Gender: Male, Average Score: 8.354140127388535
# Genre: Space, Gender: Female, Average Score: 8.566666666666666
# Genre: Sports, Gender: Female, Average Score: 8.145299145299145
# Genre: Super Power, Gender: Non-Binary, Average Score: 8.833333333333334
# Genre: Supernatural, Gender: Female, Average Score: 8.294258373205741
# Genre: Thriller, Gender: Male, Average Score: 8.42489270386266
# Genre: Vampire, Gender: Female, Average Score: 8.5
# Query duration: 1.2789456844329834 seconds

# %% [markdown]
# ### Za svako godiše, pronađi anime koji se najčešće pojavljuje među omiljenim i izračunaj njegovu prosečnu ocenu, prosek dodatnih ocena, razliku njih dve.
# ### Prikaži samo anime kod koji je ta razlika veća od nula i sortiraj po godini rođenja

# %%
pipeline5 = [
    {"$unwind": "$favorites_anime"},
    {"$group": {
        "_id": {
            "birthday": "$birthday",
            "anime_uid": "$favorites_anime"
        },
        "count": {"$sum": 1}
    }},
    {"$sort": {
        "_id.birthday": 1,
        "count": -1
    }},
    {"$group": {
        "_id": "$_id.birthday",
        "top_anime_uid": {"$first": "$_id.anime_uid"},
        "count": {"$first": "$count"}
    }},
    {"$lookup": {
        "from": "animes_opt",
        "localField": "top_anime_uid",
        "foreignField": "uid",
        "as": "anime_details"
    }},
    {"$unwind": "$anime_details"},
    {"$project": {
        "_id": 0,
        "birthday": "$_id",
        "top_anime_title": "$anime_details.title",
        "top_anime_uid": 1,
        "count": 1
    }},
    {"$sort": {
        "count": -1
    }},
    {"$lookup": {
        "from": "reviews_opt",
        "localField": "top_anime_uid",
        "foreignField": "anime_uid",
        "as": "reviews"
    }},
    {"$unwind": {
        "path": "$reviews",
        "preserveNullAndEmptyArrays": True
    }},
    {"$group": {
        "_id": {
            "birthday": "$birthday",
            "top_anime_title": "$top_anime_title",
            "top_anime_uid": "$top_anime_uid",
            "count": "$count"
        },
        "average_score": {"$avg": "$reviews.score"},
        "average_story_score": {"$avg": {"$ifNull": ["$reviews.scores.Story", 0]}},
        "average_animation_score": {"$avg": {"$ifNull": ["$reviews.scores.Animation", 0]}},
        "average_sound_score": {"$avg": {"$ifNull": ["$reviews.scores.Sound", 0]}},
        "average_character_score": {"$avg": {"$ifNull": ["$reviews.scores.Character", 0]}},
        "average_enjoyment_score": {"$avg": {"$ifNull": ["$reviews.scores.Enjoyment", 0]}}
    }},
    {"$project": {
        "_id": 0,
        "birthday": "$_id.birthday",
        "top_anime_title": "$_id.top_anime_title",
        "top_anime_uid": "$_id.top_anime_uid",
        "count": "$_id.count",
        "average_score": {"$ifNull": ["$average_score", None]},
        "average_other_scores": {
            "$avg": [
                "$average_story_score",
                "$average_animation_score",
                "$average_sound_score",
                "$average_character_score",
                "$average_enjoyment_score"
            ]
        },
        "absolute_difference": {
            "$abs": {
                "$subtract": [
                    {"$ifNull": ["$average_score", 0]},
                    {"$avg": [
                        "$average_story_score",
                        "$average_animation_score",
                        "$average_sound_score",
                        "$average_character_score",
                        "$average_enjoyment_score"
                    ]}
                ]
            }
        }
    }},
    {"$match": {
        "absolute_difference": {"$gt": 0}
    }},
    {"$sort": {
        "birthday": -1
    }}
]

start_time = time.time()

result5 = list(db.profiles_opt.aggregate(pipeline5))

end_time = time.time()
duration = end_time - start_time

print(result5)
print("Query duration:", duration, "seconds")
# Out:
# [{'birthday': 2021.0, 'top_anime_title': 'Clannad: After Story', 'top_anime_uid': 4181, 'count': 1, 'average_score': 9.547619047619047, 'average_other_scores': 9.361904761904762, 'absolute_difference': 0.18571428571428505}, {'birthday': 2018.0, 'top_anime_title': 'Clannad: After Story', 'top_anime_uid': 4181, 'count': 3, 'average_score': 9.547619047619047, 'average_other_scores': 9.361904761904762, 'absolute_difference': 0.18571428571428505}, {'birthday': 2013.0, 'top_anime_title': 'FLCL', 'top_anime_uid': 227, 'count': 2, 'average_score': 7.983870967741935, 'average_other_scores': 7.53225806451613, 'absolute_difference': 0.45161290322580516}, {'birthday': 2007.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 2, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 2006.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 4, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 2005.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 10, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1997.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 284, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1996.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 280, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1995.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 284, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1994.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 232, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1993.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 200, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1992.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 176, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1991.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 122, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1990.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 128, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1981.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid': 5114, 'count': 9, 'average_score': 9.326923076923077, 'average_other_scores': 9.003846153846155, 'absolute_difference': 0.32307692307692193}, {'birthday': 1979.0, 'top_anime_title': "Wolf's Rain", 'top_anime_uid': 202, 'count': 5, 'average_score': 8.608695652173912, 'average_other_scores': 8.343478260869565, 'absolute_difference': 0.26521739130434696}, {'birthday': 1972.0, 'top_anime_title': 'Bleach', 'top_anime_uid': 269, 'count': 2, 'average_score': 6.594594594594595, 'average_other_scores': 6.562162162162163, 'absolute_difference': 0.0324324324324321}, {'birthday': 1971.0, 'top_anime_title': 'Fullmetal Alchemist: Brotherhood', 'top_anime_uid' ...
# Query duration: 0.22630977630615234 seconds

# %% [markdown]
# ## Radovan Zoraja IN58/2020

# %%
pipeline = [
    {
        "$lookup": {
            "from": "animes_opt",
            "localField": "anime_uid",
            "foreignField": "uid",
            "as": "anime_info"
        }
    },
    {"$unwind": "$anime_info"},
    {"$match": {"anime_info.title": "Clannad: After Story", "score": {"$eq": 9}}},
    {
        "$lookup": {
            "from": "profiles_opt",
            "localField": "profile",
            "foreignField": "profile",
            "as": "profile_info"
        }
    },
    {"$unwind": "$profile_info"},
    {
        "$match": {
            "$expr": {
                "$in": ["$anime_info.uid", "$profile_info.favorites_anime"]
            }
        }
    },
    {
        "$project": {
            "_id": 0,
            "profile": 1,
            "anime_title": "$anime_info.title",
            "score": 1,
            "favorite_anime": "$profile_info.favorites_anime"
        }
    }
]

result = list(db.reviews_opt.aggregate(pipeline))
result
# Out:
# [{'profile': 'CalebTheMenace',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181,
#    11617,
#    1735,
#    35849,
#    28999,
#    29803,
#    31964,
#    36098,
#    5081,
#    8525]},
#  {'profile': 'CalebTheMenace',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181,
#    11617,
#    1735,
#    35849,
#    28999,
#    29803,
#    31964,
#    36098,
#    5081,
#    8525]},
#  {'profile': 'CalebTheMenace',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181,
#    11617,
#    1735,
#    35849,
#    28999,
#    29803,
#    31964,
#    36098,
#    5081,
#    8525]},
#  {'profile': 'CalebTheMenace',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181,
#    11617,
#    1735,
#    35849,
#    28999,
#    29803,
#    31964,
#    36098,
#    5081,
#    8525]},
#  {'profile': 'CalebTheMenace',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181,
#    11617,
#    1735,
#    35849,
#    28999,
#    29803,
#    31964,
#    36098,
#    5081,
#    8525]},
#  {'profile': 'GinKagu',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [918, 2904, 4181, 9989]},
#  {'profile': 'GinKagu',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [918, 2904, 4181, 9989]},
#  {'profile': 'GinKagu',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [918, 2904, 4181, 9989]},
#  {'profile': 'GinKagu',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [918, 2904, 4181, 9989]},
#  {'profile': 'GinKagu',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [918, 2904, 4181, 9989]},
#  {'profile': 'PapaCow',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181, 16742, 10620, 433]},
#  {'profile': 'PapaCow',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181, 16742, 10620, 433]},
#  {'profile': 'PapaCow',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181, 16742, 10620, 433]},
#  {'profile': 'PapaCow',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181, 16742, 10620, 433]},
#  {'profile': 'PapaCow',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181, 16742, 10620, 433]},
#  {'profile': 'ExtremelyToxic',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [37786,
#    34599,
#    199,
#    11061,
#    4181,
#    37450,
#    20,
#    35839,
#    32281,
#    32995,
#    28999,
#    33506,
#    37510,
#    38000,
#    34577,
#    1735,
#    4224,
#    9989,
#    28851,
#    38993]},
#  {'profile': 'ExtremelyToxic',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [37786,
#    34599,
#    199,
#    11061,
#    4181,
#    37450,
#    20,
#    35839,
#    32281,
#    32995,
#    28999,
#    33506,
#    37510,
#    38000,
#    34577,
#    1735,
#    4224,
#    9989,
#    28851,
#    38993]},
#  {'profile': 'ExtremelyToxic',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [37786,
#    34599,
#    199,
#    11061,
#    4181,
#    37450,
#    20,
#    35839,
#    32281,
#    32995,
#    28999,
#    33506,
#    37510,
#    38000,
#    34577,
#    1735,
#    4224,
#    9989,
#    28851,
#    38993]},
#  {'profile': 'ExtremelyToxic',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [37786,
#    34599,
#    199,
#    11061,
#    4181,
#    37450,
#    20,
#    35839,
#    32281,
#    32995,
#    28999,
#    33506,
#    37510,
#    38000,
#    34577,
#    1735,
#    4224,
#    9989,
#    28851,
#    38993]},
#  {'profile': 'ExtremelyToxic',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [37786,
#    34599,
#    199,
#    11061,
#    4181,
#    37450,
#    20,
#    35839,
#    32281,
#    32995,
#    28999,
#    33506,
#    37510,
#    38000,
#    34577,
#    1735,
#    4224,
#    9989,
#    28851,
#    38993]},
#  {'profile': 'MiniOniOG',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [11061,
#    31240,
#    1535,
#    35790,
#    22199,
#    37450,
#    35849,
#    30276,
#    4181,
#    28999]},
#  {'profile': 'MiniOniOG',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [11061,
#    31240,
#    1535,
#    35790,
#    22199,
#    37450,
#    35849,
#    30276,
#    4181,
#    28999]},
#  {'profile': 'MiniOniOG',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [11061,
#    31240,
#    1535,
#    35790,
#    22199,
#    37450,
#    35849,
#    30276,
#    4181,
#    28999]},
#  {'profile': 'MiniOniOG',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [11061,
#    31240,
#    1535,
#    35790,
#    22199,
#    37450,
#    35849,
#    30276,
#    4181,
#    28999]},
#  {'profile': 'MiniOniOG',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [11061,
#    31240,
#    1535,
#    35790,
#    22199,
#    37450,
#    35849,
#    30276,
#    4181,
#    28999]},
#  {'profile': 'crazyangst12',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181]},
#  {'profile': 'crazyangst12',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181]},
#  {'profile': 'crazyangst12',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181]},
#  {'profile': 'crazyangst12',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181]},
#  {'profile': 'crazyangst12',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [4181]},
#  {'profile': 'gabrielbernardo',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [1535, 4181, 11061, 5114]},
#  {'profile': 'gabrielbernardo',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [1535, 4181, 11061, 5114]},
#  {'profile': 'gabrielbernardo',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [1535, 4181, 11061, 5114]},
#  {'profile': 'gabrielbernardo',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [1535, 4181, 11061, 5114]},
#  {'profile': 'gabrielbernardo',
#   'score': 9,
#   'anime_title': 'Clannad: After Story',
#   'favorite_anime': [1535, 4181, 11061, 5114]}]

# %%
pipeline = [
    {
        "$lookup": {
            "from": "animes_opt",
            "localField": "anime_uid",
            "foreignField": "uid",
            "as": "anime_info"
        }
    },
    {"$unwind": "$anime_info"},
    {"$match": {"anime_info.genre": "Action"}},
    {
        "$group": {
            "_id": "$profile",
            "total_reviews": {"$sum": 1}
        }
    },
    {
        "$project": {
            "_id": 0,
            "profile": "$_id",
            "total_reviews": 1
        }
    },
    {"$sort": {"total_reviews": -1}},
    {"$limit": 5}
]
result = list(db.reviews_opt.aggregate(pipeline))
result
# Out:
# [{'total_reviews': 16, 'profile': 'ggultra2764'},
#  {'total_reviews': 13, 'profile': 'literaturenerd'},
#  {'total_reviews': 12, 'profile': 'FullmetalCowboy'},
#  {'total_reviews': 12, 'profile': 'BowlingJD'},
#  {'total_reviews': 9, 'profile': 'HybridMedia'}]

# %%
pipeline = [
    {
        "$lookup": {
            "from": "profiles_opt",
            "localField": "profile",
            "foreignField": "profile",
            "as": "profile_info"
        }
    },
    {"$unwind": "$profile_info"},
    {"$match": {"profile_info.gender": "Non-Binary"}},
    {
        "$group": {
            "_id": "$anime_uid",
            "average_score": {"$avg": "$scores.Animation"}
        }
    },
    {
        "$lookup": {
            "from": "animes_opt",
            "localField": "_id",
            "foreignField": "uid",
            "as": "anime_info"
        }
    },
    {"$unwind": "$anime_info"},
    {
        "$project": {
            "_id": 0,
            "anime_title": "$anime_info.title",
            "average_score": 1
        }
    },
    {"$sort": {"average_score": -1}},
    {"$limit": 100}
]
result = list(db.reviews_opt.aggregate(pipeline))
result
# Out:
# [{'average_score': 10.0, 'anime_title': 'Overlord'},
#  {'average_score': 10.0, 'anime_title': 'Colorful (Movie)'},
#  {'average_score': 10.0, 'anime_title': 'One Punch Man'},
#  {'average_score': 10.0, 'anime_title': 'Zetsuen no Tempest'},
#  {'average_score': 10.0, 'anime_title': 'Byousoku 5 Centimeter'},
#  {'average_score': 10.0, 'anime_title': 'Seihou Bukyou Outlaw Star'},
#  {'average_score': 10.0, 'anime_title': 'Hataraku Maou-sama!'},
#  {'average_score': 10.0, 'anime_title': 'Tanaka-kun wa Itsumo Kedaruge'},
#  {'average_score': 10.0, 'anime_title': 'Shirokuma Cafe'},
#  {'average_score': 10.0, 'anime_title': 'Little Witch Academia'},
#  {'average_score': 10.0, 'anime_title': 'Little Witch Academia (TV)'},
#  {'average_score': 10.0, 'anime_title': 'Tekkon Kinkreet'},
#  {'average_score': 10.0, 'anime_title': 'Haibane Renmei'},
#  {'average_score': 9.5, 'anime_title': 'Higashi no Eden'},
#  {'average_score': 9.0, 'anime_title': 'Non Non Biyori'},
#  {'average_score': 9.0, 'anime_title': 'Naruto'},
#  {'average_score': 9.0, 'anime_title': 'Full Metal Panic! The Second Raid'},
#  {'average_score': 9.0, 'anime_title': 'Soul Eater'},
#  {'average_score': 9.0, 'anime_title': 'Serial Experiments Lain'},
#  {'average_score': 9.0, 'anime_title': 'Charlotte'},
#  {'average_score': 9.0, 'anime_title': 'Fairy Tail (2014)'},
#  {'average_score': 9.0, 'anime_title': 'Bungou Stray Dogs: Dead Apple'},
#  {'average_score': 9.0, 'anime_title': 'Saraiya Goyou'},
#  {'average_score': 9.0, 'anime_title': 'Sekaiichi Hatsukoi'},
#  {'average_score': 9.0, 'anime_title': 'Terra e... (TV)'},
#  {'average_score': 9.0, 'anime_title': 'Omae Umasou da na'},
#  {'average_score': 9.0, 'anime_title': 'Kuroshitsuji'},
#  {'average_score': 8.0, 'anime_title': 'InuYasha Movie 3: Tenka Hadou no Ken'},
#  {'average_score': 8.0, 'anime_title': 'Asagao to Kase-san.'},
#  {'average_score': 8.0, 'anime_title': 'Mahoujin Guruguru (2017)'},
#  {'average_score': 8.0, 'anime_title': 'Carole & Tuesday'},
#  {'average_score': 7.8, 'anime_title': 'K-On!'},
#  {'average_score': 7.5, 'anime_title': 'Yagate Kimi ni Naru'},
#  {'average_score': 7.333333333333333, 'anime_title': 'Yuri!!! on Ice'},
#  {'average_score': 7.333333333333333,
#   'anime_title': 'Higurashi no Naku Koro ni'},
#  {'average_score': 7.0, 'anime_title': 'Baby Steps'},
#  {'average_score': 7.0, 'anime_title': 'Jormungand'},
#  {'average_score': 7.0,
#   'anime_title': "Kyoukai no Kanata Movie: I'll Be Here - Kako-hen - Yakusoku no Kizuna"},
#  {'average_score': 7.0, 'anime_title': 'Koukaku Kidoutai 2: Innocence'},
#  {'average_score': 7.0, 'anime_title': 'Tiger & Bunny'},
#  {'average_score': 7.0, 'anime_title': 'Gake no Ue no Ponyo'},
#  {'average_score': 7.0, 'anime_title': '91 Days'},
#  {'average_score': 7.0, 'anime_title': 'InuYasha (TV)'},
#  {'average_score': 6.5, 'anime_title': 'FLCL'},
#  {'average_score': 6.0, 'anime_title': 'Drifters'},
#  {'average_score': 6.0, 'anime_title': 'Devilman: Crybaby'},
#  {'average_score': 6.0, 'anime_title': 'Top wo Nerae! Gunbuster'},
#  {'average_score': 5.333333333333333, 'anime_title': 'Tokyo Ghoul'},
#  {'average_score': 4.0, 'anime_title': 'Ergo Proxy'},
#  {'average_score': 3.0, 'anime_title': 'Kanon (2006)'},
#  {'average_score': 1.0, 'anime_title': 'Eyeshield 21'},
#  {'average_score': 0.0,
#   'anime_title': 'Gate: Jieitai Kanochi nite, Kaku Tatakaeri 2nd Season'}]

# %%
pipeline = [
    {
        "$lookup": {
            "from": "profiles_opt",
            "localField": "profile",
            "foreignField": "profile",
            "as": "profile_info"
        }
    },
    {"$unwind": "$profile_info"},
    {
        "$match": {
            "profile_info.gender": "Female",
            "profile_info.birthday": {"$gte": 1995, "$lte": 2005}
        }
    },
    {
        "$group": {
            "_id": "$anime_uid",
            "total_reviews": {"$sum": 1}
        }
    },
    {
        "$lookup": {
            "from": "animes_opt",
            "localField": "_id",
            "foreignField": "uid",
            "as": "anime_info"
        }
    },
    {"$unwind": "$anime_info"},
    {
        "$project": {
            "_id": 0,
            "anime_title": "$anime_info.title",
            "total_reviews": 1
        }
    },
    {"$sort": {"total_reviews": -1}},
    {"$limit": 10}
]

result = list(db.reviews_opt.aggregate(pipeline))
result
# Out:
# [{'total_reviews': 52, 'anime_title': 'Yuri!!! on Ice'},
#  {'total_reviews': 52, 'anime_title': 'Yuri!!! on Ice'},
#  {'total_reviews': 45, 'anime_title': 'Kuroshitsuji'},
#  {'total_reviews': 45, 'anime_title': 'Kuroshitsuji'},
#  {'total_reviews': 45, 'anime_title': 'Kuroshitsuji'},
#  {'total_reviews': 45, 'anime_title': 'Kuroshitsuji'},
#  {'total_reviews': 45, 'anime_title': 'Kuroshitsuji'},
#  {'total_reviews': 45, 'anime_title': 'Kuroshitsuji'},
#  {'total_reviews': 45, 'anime_title': 'Kuroshitsuji'},
#  {'total_reviews': 28, 'anime_title': 'Charlotte'}]

# %%
pipeline = [
    {
        "$lookup": {
            "from": "profiles_opt",
            "localField": "profile",
            "foreignField": "profile",
            "as": "profile_info"
        }
    },
    {"$unwind": "$profile_info"},
    {
        "$group": {
            "_id": {
                "anime_uid": "$anime_uid",
                "gender": "$profile_info.gender"
            },
            "average_score": {"$avg": "$score"}
        }
    },
    {
        "$group": {
            "_id": "$_id.anime_uid",
            "scores_by_gender": {
                "$push": {
                    "gender": "$_id.gender",
                    "average_score": "$average_score"
                }
            }
        }
    },
    {
        "$project": {
            "_id": 0,
            "anime_uid": "$_id",
            "score_diff": {
                "$abs": {
                    "$subtract": [
                        {"$arrayElemAt": ["$scores_by_gender.average_score", 1]},
                        {"$arrayElemAt": ["$scores_by_gender.average_score", 0]}
                    ]
                }
            }
        }
    },
    {
        "$lookup": {
            "from": "animes_opt",
            "localField": "anime_uid",
            "foreignField": "uid",
            "as": "anime_info"
        }
    },
    {"$unwind": "$anime_info"},
    {
        "$project": {
            "anime_title": "$anime_info.title",
            "score_diff": 1
        }
    },
    {"$sort": {"score_diff": -1}},
    {"$limit": 4}
]
result = list(db.reviews_opt.aggregate(pipeline))
result
# Out:
# [{'score_diff': 6.538461538461538, 'anime_title': 'Eyeshield 21'},
#  {'score_diff': 6.538461538461538, 'anime_title': 'Eyeshield 21'},
#  {'score_diff': 6.538461538461538, 'anime_title': 'Eyeshield 21'},
#  {'score_diff': 6.538461538461538, 'anime_title': 'Eyeshield 21'}]
